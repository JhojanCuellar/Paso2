# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

data = pd.read_csv("D:/Desktop/framingham.csv", sep=",")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
data[['age','diabetes']]
# Out:
#       age  diabetes
# 0      39         0
# 1      46         0
# 2      48         0
# 3      61         0
# 4      46         0
# ...   ...       ...
# 4233   50         0
# 4234   51         0
# 4235   48         0
# 4236   44         0
# 4237   52         0
#
# [4238 rows x 2 columns]

# %%
data[['age','diabetes']].plot.scatter(x='age',y='diabetes')
# Out:
# <Axes: xlabel='age', ylabel='diabetes'>

# %%
n = 30
m = 70

# %%
x = np.linspace(0,data['diabetes'].max(),70)
y = 1/(1+np.exp(-(w*x+b)))

# %%
data.plot.scatter(x='diabetes',y='age')
plt.plot(x, y, color='red')
plt.ylim(0,data['age'].max()*1.1)
plt.xlabel('indice de diabetes')
plt.ylabel('edades promedio')
plt.show()
